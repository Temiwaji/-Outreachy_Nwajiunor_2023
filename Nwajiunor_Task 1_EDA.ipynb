# %% [markdown]
# # Charting the Path to Sustainability: Integrating Land Sector Data with SDGs
# ## Task 1- Land sector management and Exploratory Data Analysis (EDA)
# ### Case in Study; Nigeria

# %% [markdown]
# ![Nigerian-map-e1648026092438.webp](attachment:Nigerian-map-e1648026092438.webp)

# %% [markdown]
# #### TABLE OF CONTENT

# %% [markdown]
# #### 1. INTRODUCTION
#     1.0 OVERVIEW
#     1.1 DATA DESCRIPTION

# %% [markdown]
# #### 2. REPOSITORY
#     2.0 IMPORT LIBRARIES

# %% [markdown]
# #### 3. ADMINISTRATIVE
#      3.O BOUNDARY
#      3.1 PROTECTED AREAS
#      3.2 ROAD NETWORK

# %% [markdown]
# #### 4. BIOCLIMATIC AND ECOLOGICAL ZONES
#     4.0 ECOLOGICAL ZONES
#     4.1 AGRO ECOLOGICAL ZONES
#     4.2 BIODIVERSITY

# %% [markdown]
# #### 5. LANDCOVER
#      5.0 PLANTED FORESTS

# %% [markdown]
# #### 6 SOIL RESOUURCES
#      6.0 SOIL RESOURCES

# %% [markdown]
# #### 7 SUMMARY

# %% [markdown]
# #### REFERENCES

# %% [markdown]
# #### INTRODUCTION
#     1.0 OVERVIEW

# %% [markdown]
# Nigeria, located in West Africa, shares its borders with the Republic of Benin to the west, Chad and Cameroon to the east, and Niger to the north. To the south, it boasts a coastline along the Gulf of Guinea and borders Lake Chad to the northeast. The country is marked by diverse geographical features, including the Adamawa Plateau, Mambilla Plateau, Jos Plateau, Obudu Plateau, the Niger River, Benue River, and Niger Delta.
#
# Nigeria falls within the tropical region, characterized by a climate that is seasonally humid and highly humid. The country experiences four distinct climate types, generally transitioning from south to north.
#
# Covering an area of 923,768 km², Nigeria's primary rivers are the Niger, from which it derives its name, and the Benue, a major tributary of the Niger. The highest point in the country is Chappal Waddi (or Gangirwal), standing at 2,419 m (7,936 ft.), located in the Adamawa mountains within the Gashaka-Gumti National Park, Taraba State, near the border with Cameroon.
#
# Abuja serves as the capital city, strategically situated in the heart of the nation, while Lagos functions as Nigeria's principal port, economic hub, and its largest city. The official languages spoken in Nigeria are English, Hausa, Igbo, and Yoruba, reflecting the country's rich linguistic diversity, with an estimated 250 distinct ethno-linguistic groups.

# %% [markdown]
#     1.1 AIM

# %% [markdown]
# The aim of the analysis is to carry out Exploratory Data Analysis on the administrative, biodiversity, climate, land cover and soil categories of the land sector dataset for Nigeria.

# %% [markdown]
# #### REPOSITORY
#     2.0 IMPORT LIBRARIES

# %% [markdown]
# Importing libraries is a critical step before loading the dataset. It is critical to import only the libraries that you are certain you will need to work with your dataset. To import to libraries, use the keyword import.

# %%
# Import all necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import gdown
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### ADMINISTRATIVE

# %% [markdown]
#      3.1 BOUNDARY

# %% [markdown]
#      LOAD DATASET

# %%
# Load dataset to define Nigeria's admin boundaries
nga_admin = (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\NGA_AL2_Nigeria.json")

# Read geojson file into a geodataframe
nga_admin_gdf = gpd.read_file(nga_admin) 
nga_admin_gdf
# Out:
#   country ISO3166_2     name   enname  locname offname        boundary  \
# 0     NGA            Nigeria  Nigeria  Nigeria          administrative
#
#    adminlevel wikidata   wikimedia           timestamp  \
# 0           2    Q1033  en:Nigeria 2019-09-18 23:02:02
#
#                                             geometry
# 0  MULTIPOLYGON (((6.44714 4.30935, 6.44678 4.309...

# %%
# Check no.of rows and columns for Nigeria's admin boundary dataframme
nga_admin_gdf.shape
# Out:
# (1, 12)

# %%
# Load the dataset for all states in Nigeria
ngastates_admin = (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\NGA_ALL_states.json")

# Read geojson file into a geodataframe
ngastates_admin_gdf = gpd.read_file(ngastates_admin)
ngastates_admin_gdf.head(2)
# Out:
#   country ISO3166_2     name enname  locname offname        boundary  \
# 0     NGA     NG-AB     Abia            Abia          administrative
# 1     NGA     NG-AD  Adamawa         Adamawa          administrative
#
#    adminlevel wikidata         wikimedia           timestamp  \
# 0           4  Q320852     en:Abia State 2019-09-18 23:02:02
# 1           4  Q337514  en:Adamawa State 2019-02-26 10:52:47
#
#                                             geometry
# 0  POLYGON ((7.14043 4.90063, 7.14375 4.89561, 7....
# 1  POLYGON ((11.34152 8.01867, 11.34614 8.01523, ...

# %%
# Check no.of rows and columns for states in Nigeria boundaries dataframe
ngastates_admin_gdf.shape
# Out:
# (37, 12)

# %% [markdown]
#     DEFINE THE BOUNDARY

# %%
# Create subplot with two panels
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

# Plot the administrative boundary of Nigeria in panel 1
nga_admin_gdf.plot(ax=ax1, color="green", edgecolor="yellow")
ax1.set_title("ADMINISTRATIVE BOUNDARY IN NIGERIA")

# Plot the administrative boundaries of all states in panel 2
ngastates_admin_gdf.plot(ax=ax2, color="green", edgecolor="yellow")
ax2.set_title("ADMINISTRATIVE BOUNDARY FOR ALL STATES IN NIGERIA")

plt.show()

# %% [markdown]
#     3.1 PROTECTED AREAS

# %%
# Load dataset to define world database of protected areas
wdpa = (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\WDPA_WDOECM_wdpa_gdb_polygons\WDPA_WDOECM_wdpa_gdb_polygons.shx")

# Read the shapefile into geodataframe
protected_areas_gdf = gpd.read_file(wdpa)
protected_areas_gdf.head(2)
# Out:
#      WDPAID  WDPA_PID PA_DEF  \
# 0   10715.0     10715      1
# 1  209777.0  209777_E      1
#
#                                                 NAME              ORIG_NAME  \
# 0                                         Kronotskiy             Kronotskiy
# 1  Sarali Land between Rivers / Great Volzhsko-Ka...  Great Volzhsko-Kamsky
#
#                           DESIG                     DESIG_ENG     DESIG_TYPE  \
# 0  UNESCO-MAB Biosphere Reserve  UNESCO-MAB Biosphere Reserve  International
# 1  UNESCO-MAB Biosphere Reserve  UNESCO-MAB Biosphere Reserve  International
#
#          IUCN_CAT        INT_CRIT  ...     MANG_AUTH     MANG_PLAN  \
# 0  Not Applicable  Not Applicable  ...  Not Reported  Not Reported
# 1  Not Applicable  Not Applicable  ...  Not Reported  Not Reported
#
#             VERIF  METADATAID  SUB_LOC PARENT_ISO  ISO3       SUPP_INFO  \
# 0  State Verified         840   RU-KAM        RUS   RUS  Not Applicable
# ...

# %%
# Check no.of rows and columns for global protected areas dataframe
protected_areas_gdf.shape
# Out:
# (240165, 31)

# %%
# Filter data for Nigeria
nga_protected_areas_gdf = protected_areas_gdf[protected_areas_gdf["PARENT_ISO"] == "NGA"]

# %%
# Create plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the protected areas in Nigeria
nga_protected_areas_gdf.plot(ax=ax, cmap = "viridis", edgecolor="black")

plt.title("PROTECTED AREAS IN NIGERIA")

plt.show()

# %% [markdown]
#     3.2 ROAD NETWORK

# %%
# Load dataset to define global roads open access
global_roads= (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\Global Roads Open Access Data Set_dissolved.json")

# Read the json into geodataframe
global_roads_gdf = gpd.read_file(global_roads)

# %%
global_roads_gdf.head(2)
# Out:
#    OBJECTID ONME  FCLASS  SRFTPE  ISSEASONAL  CURNTPRAC  GDWTHRPRAC  \
# 0         1  NaN       0     0.0         0.0        NaN         NaN
# 1         2  NaN       0     0.0         0.0        NaN         NaN
#
#    SUM_LENGTH_KM                                           geometry
# 0    16686.65607  LINESTRING (-66.82451 17.98029, -66.82455 17.9...
# 1    16686.65607  LINESTRING (-66.62012 17.98131, -66.62126 17.9...

# %%
# Check no.of rows and columns for global roads dataframe
global_roads_gdf.shape
# Out:
# (1101300, 9)

# %%
# Perform a spatial join to select roads within Nigeria
roads_in_nigeria = gpd.sjoin(global_roads_gdf, nga_admin_gdf, how="inner", op="intersects")

# Reset the index of the resulting GeoDataFrame
roads_in_nigeria.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
# Create plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the administrative boundary of Nigeria
nga_admin_gdf.plot(ax=ax, color="green", edgecolor="yellow")

# Plot the road network
roads_in_nigeria.plot(ax=ax, color="blue", linewidth=0.5)

plt.title("ROAD NETWORKS IN NIGERIA")

plt.show()

# %% [markdown]
# #### BIOCLIMATIC AND ECOLOGICAL ZONES

# %% [markdown]
#     4.0 ECOLOGICAL ZONES

# %%
# Load dataset to define country's ecological zones
nga_ecozones = (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\NGA_AL2_Nigeria_GEZ.json")
nga_ecozones_gdf = gpd.read_file(nga_ecozones) 
nga_ecozones_gdf.head(2)
# Out:
#   country ISO3166_2     name               gez_name  gez_code gez_abbrev  \
# 0     NGA            Nigeria    Tropical dry forest        13       TAwb
# 1     NGA            Nigeria  Tropical moist forest        12       TAwa
#
#    adminlevel                                           geometry
# 0           2  POLYGON ((4.17387 12.70964, 3.91224 12.72630, ...
# 1           2  POLYGON ((6.12077 12.05414, 6.01167 12.05684, ...

# %%
# Create plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the ecological zones
nga_ecozones_gdf.plot(column='gez_name', cmap='viridis', ax=ax, legend=True)

plt.title("ECOLOGICAL ZONES IN NIGERIA")

# Add a legend
legend = ax.get_legend()
legend.set_title("ECOLOGICAL ZONES")
legend.set_bbox_to_anchor((1, 0.3)) 

plt.show()

# %% [markdown]
#     4.1 AGROECOLOGICAL ZONES

# %%
# Load dataset to define global agroecological zones dataset
global_aeczones= (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\GlobalAgroEcologicalZones_GAEZ.geojson")

# Read the json into geodataframe
global_aeczones_gdf = gpd.read_file(global_aeczones)
global_aeczones_gdf.head(2)
# Out:
#    Value                                           geometry
# 0      1  POLYGON ((-33.50000 83.65000, -33.50000 83.500...
# 1      1  POLYGON ((-37.85000 83.60000, -37.85000 83.500...

# %%
# Check no.of rows and columns for global ecological zones
global_aeczones_gdf.shape
# Out:
# (116675, 2)

# %%
# Check for unique values present in the value column
global_aeczones_gdf["Value"].unique()
# Out:
# array([ 1,  2, 18, 14, 11, 12, 13,  5, 10,  9, 17,  8, 16, 15,  4,  6,  7,
#         3], dtype=int64)

# %%
# Fix the data and replace numbers with acgroecological zones

values = {"1": "Tropical-Arid", "2": "Tropical-Dry Semi-Arid", "3": "Tropical -Moist Semi-Arid", "4": "Tropical-Sub-Humid", "5": "Tropical-Humid", 
          "6": "Tropical-Humid (year round)", "7": "Temperate-Arid", "8": "Temperate-Dry Semi-Arid", "9": "Temperate-Moist Semi-Arid", 
          "10": "Temperate-Sub-Humid", "11": "Temperate-Humid", "12": "Temperate-Humid (year round)", "13": "Boreal-Arid", 
          "14": "Boreal-Dry Semi-Arid", "15": "Boreal-Moist Semi-Arid", "16": "Boreal-Sub-humid", "17": "Boreal-Humid", 
          "18": "Boreal-Humid (year round)"}

# %%
# Standardize the column names
global_aeczones_gdf.columns = global_aeczones_gdf.columns.str.lower()

# %%
# Rename class name
global_aeczones_gdf.value = global_aeczones_gdf.value.astype("str").replace(values)

# %%
# Check to see replaced values
global_aeczones_gdf.head(2)
# Out:
#            value                                           geometry
# 0  Tropical-Arid  POLYGON ((-33.50000 83.65000, -33.50000 83.500...
# 1  Tropical-Arid  POLYGON ((-37.85000 83.60000, -37.85000 83.500...

# %%
# Extract Nigeria's agroecological zones
ngaaeczones_gdf = global_aeczones_gdf.clip(nga_admin_gdf)
ngaaeczones_gdf = ngaaeczones_gdf.reset_index(drop=True)

# %%
ngaaeczones_gdf.head(2)
# Out:
#                        value  \
# 0           Boreal-Sub-humid
# 1  Boreal-Humid (year round)
#
#                                             geometry
# 0  MULTIPOLYGON (((11.65000 7.00000, 11.67065 7.0...
# 1  POLYGON ((7.60000 4.50000, 7.65000 4.50000, 7....

# %%
# Check no.of rows and columns for Nigeria's agro ecological zones
ngaaeczones_gdf.shape
# Out:
# (546, 2)

# %%
# Create plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the ecological zones
ngaaeczones_gdf.plot(column="value", cmap="viridis", ax=ax, legend=True)

plt.title("AGRO ECOLOGICAL ZONES IN NIGERIA")

# Add a legend
legend = ax.get_legend()
legend.set_title("AGRO ECOLOGICAL ZONES")
legend.set_bbox_to_anchor((1, 0.01)) 

plt.show()

# %% [markdown]
#     4.2 BIODIVERSITY HOTSPOTS

# %%
# Load dataset to define global biodiversity hotspots
global_biodivhotspots= (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\CI_BiodiversityHotspots (1).geojson")
# Read the json into geodataframe
global_biodivhotspots_gdf = gpd.read_file(global_biodivhotspots)
global_biodivhotspots_gdf.head(2)
# Out:
#    OBJECTID                                           NAME          Type  \
# 0         1  Chilean Winter Rainfall and Valdivian Forests  hotspot area
# 1         2  Chilean Winter Rainfall and Valdivian Forests   outer limit
#
#    Shape_Length  Shape_Area                                           geometry
# 0    200.706891   40.754665  MULTIPOLYGON (((-74.59792 -46.92502, -74.61111...
# 1    191.174978  186.085694  POLYGON ((-70.30946 -22.96028, -70.48596 -22.7...

# %%
# Check no.of rows and columns for global biodiversity hospots
global_biodivhotspots_gdf.shape
# Out:
# (53, 6)

# %%
# Extract Nigeria's biodiversity hotspots
nga_biodivhotspots_gdf = global_biodivhotspots_gdf.clip(nga_admin_gdf)
nga_biodivhotspots_gdf = nga_biodivhotspots_gdf.reset_index(drop=True)

# %%
nga_biodivhotspots_gdf.head(2)
# Out:
#    OBJECTID                            NAME          Type  Shape_Length  \
# 0        41  Guinean Forests of West Africa  hotspot area     133.08195
#
#    Shape_Area                                           geometry
# 0    50.52551  MULTIPOLYGON (((10.76048 7.37974, 10.74016 7.3...

# %%
# Check no.of rows and columns for Nigeria's biodiversity hotspots
nga_biodivhotspots_gdf.shape
# Out:
# (1, 6)

# %%
 # Create subplot with two panels
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

# Plot the hotspots by name in panel 1
nga_biodivhotspots_gdf.plot(column="NAME", cmap="viridis", ax=ax1, legend=True)
nga_admin_gdf.plot(ax=ax1, color="green", edgecolor="yellow", alpha = 0.3)
ax1.set_title("BIODIVERSITY HOTSPOTS IN NIGERIA BY NAME")

# Plot the hotspots by type in panel 2
nga_biodivhotspots_gdf.plot(column="Type", cmap="viridis", ax=ax2, legend=True)
nga_admin_gdf.plot(ax=ax2, color="green", edgecolor="yellow", alpha = 0.3)
ax2.set_title("ABIODIVERSITY HOTSPOTS IN NIGERIA BY TYPE")

plt.show()

# %% [markdown]
# #### LAND COVER

# %% [markdown]
#     5.0 PLANTED FORESTS

# %%
# Load dataset to define Nigeria's planted forests
plantforests = (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\NGA_Nigeria_SDPT.json")

# Read the json into geodataframe
nga_plantforests_gdf = gpd.read_file(plantforests)
nga_plantforests_gdf.head(2)
# Out:
#   final_id  iso  country  org_name common_name            species  \
# 0    NGA_0  NGA  Nigeria  oil palm    Oil Palm  Elaeis guineensis
# 1    NGA_0  NGA  Nigeria  oil palm    Oil Palm  Elaeis guineensis
#
#   species_simp    plant_ag   timber_ag ever_dec conifer_broad hard_soft  \
# 0    Oil Palm   Tree crops  Tree crops      n/a           n/a       n/a
# 1    Oil Palm   Tree crops  Tree crops      n/a           n/a       n/a
#
#       size source       year  \
# 0  Unknown    WRI  2013-2015
# 1  Unknown    WRI  2013-2015
#
#                                             geometry
# 0  POLYGON ((6.73408 5.07584, 6.73217 5.09476, 6....
# 1  POLYGON ((6.93543 5.18647, 6.90801 5.18638, 6....

# %%
# Check for the no.of rows and columns
nga_plantforests_gdf.shape
# Out:
# (85, 16)

# %%
# Check for unique values present in the value column
nga_plantforests_gdf["common_name"].unique()
# Out:
# array(['Oil Palm'], dtype=object)

# %%
# Check for unique values present in the value column
nga_plantforests_gdf["species"].unique()
# Out:
# array(['Elaeis guineensis'], dtype=object)

# %%
# Create subplot with three panels
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))

# Plot the hotspots by name in panel 1
nga_plantforests_gdf.plot(column="common_name", cmap="viridis", ax=ax1, legend=True)
nga_admin_gdf.plot(ax=ax1, color="green", edgecolor="yellow", alpha = 0.3)
ax1.set_title("PLANTED FORESTS IN NIGERIA BY SPECIES COMMON NAME")

# Plot the planted forests by type in panel 2
nga_plantforests_gdf.plot(column="species", cmap="viridis", ax=ax2, legend=True)
nga_admin_gdf.plot(ax=ax2, color="green", edgecolor="yellow", alpha = 0.3)
ax2.set_title("PLANTED FORESTS IN NIGERIA BY SPECIES")

# Plot the planted forests by plantation in panel 3
nga_plantforests_gdf.plot(column="plant_ag", cmap="viridis", ax=ax3, legend=True)
nga_admin_gdf.plot(ax=ax3, color="green", edgecolor="yellow", alpha = 0.3)
ax3.set_title("PLANTED FORESTS IN NIGERIA BY PLANTATION")

plt.show()

# %% [markdown]
# #### SOIL

# %% [markdown]
#     6.0 SOIL RESOURCES

# %%
# Load dataset to define Nigeria's soil resources
nga_soil_resources = (r"C:\Users\User\Documents\Scholarships application\Women Techstars Application\internships\Outreachy\Contribution\Outreachy_Nwajiunor_2023\NGA_AL2_Nigeria_WSR.json")
nga_soil_resources_gdf = gpd.read_file(nga_soil_resources) 
nga_soil_resources_gdf.head(2)
# Out:
#   country ISO3166_2     name SNAME  mg_code      IPCC  adminlevel  \
# 0     NGA            Nigeria    AC       23   Acrisol           2
# 1     NGA            Nigeria    AR        3  Arenosol           2
#
#                                             geometry
# 0  MULTIPOLYGON (((11.51913 6.61454, 11.51960 6.6...
# 1  POLYGON ((5.83178 13.76125, 5.78032 13.78030, ...

# %%
# Check no.of rows and columns for Nigeria's Soil Resources
nga_soil_resources_gdf.shape
# Out:
# (7, 8)

# %%
# Create plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the ecological zones
nga_soil_resources_gdf.plot(column="IPCC", cmap="viridis", ax=ax, legend=True)

plt.title("SOIL RESOURCES IN NIGERIA")

# Add a legend
legend = ax.get_legend()
legend.set_title("SOIL RESOURCES")
legend.set_bbox_to_anchor((1, 0.3))

# %% [markdown]
# #### SUMMARY

# %% [markdown]
# Nigeria, located in West Africa, boasts diverse natural features and abundant resources. The country hosts protected areas that safeguard its unique biodiversity and features an extensive road network connecting regions both domestically and beyond its borders.
#
# Nigeria's ecological zones encompass a rich variety of environments, including tropical dry forests, moist forests, mountain systems, rainforests, shrublands, and water bodies. The tropical mountain system stands as the largest among these ecological zones, contributing to the nation's rich natural heritage.
#
# Regarding agro-ecological zones, Nigeria exhibits a wide range of climates and agricultural potential. These zones encompass various categories, such as Tropical-Arid, Tropical-Dry Semi-Arid, Tropical-Moist Semi-Arid, Tropical-Sub-Humid, Tropical-Humid, Tropical-Humid (year-round), Temperate-Arid, Temperate-Dry Semi-Arid, Temperate-Moist Semi-Arid, Temperate-Sub-Humid, Temperate-Humid, Temperate-Humid (year-round), Boreal-Arid, Boreal-Dry Semi-Arid, Boreal-Moist Semi-Arid, Boreal-Sub-humid, Boreal-Humid, and Boreal-Humid (year-round). The Boreal-Dry Semi-Arid zone stands as the largest, fostering diverse agricultural practices and crop cultivation in Nigeria.
#
# The Guinean Forests of West Africa represent a biodiversity hotspot in the region, contributing to the country's ecological significance. These lush forests are home to an array of unique species and play a vital role in maintaining the ecological balance.
#
# Oil palm, scientifically known as Elaeis guineensis, plays a significant role in Nigeria's economy, yielding valuable products like palm oil and palm kernel oil.
#
# The country's soil resources encompass various types, including ariesols, arenosols, fluvisols, gleyisols, lixisols, verisols, and water bodies, with lixisols being the most prominent. These soils significantly influence land use, agricultural practices, and ecological dynamics across the nation.

# %% [markdown]
# #### REFERENCES

# %% [markdown]
# https://en.wikipedia.org/wiki/Geography_of_Nigeria
#
# https://www.researchgate.net/publication/263417667_Agro-ecological_Zone_Emission_Factor_AEZ-EF_Model_v47
